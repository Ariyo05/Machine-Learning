# %% [markdown]
# # USING CLUSTER MODELTO GROUP ALCOHOL INTO DIFFERENT CLUSTERS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORTING THE DATASET

# %%
df = pd.read_csv('wine.data')
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %% [markdown]
# ### Removing the first column from the DATASET

# %%
df = df.iloc[:, -13:]
df
# Out:
#      14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  3.92  \
# 0    13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05  3.40
# 1    13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03  3.17
# 2    14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86  3.45
# 3    13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04  2.93
# 4    14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05  2.85
# ..     ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...   ...
# 172  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64  1.74
# 173  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70  1.56
# 174  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59  1.56
# 175  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60  1.62
# 176  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61  1.60
#
#      1065
# 0    1050
# 1    1185
# ...

# %% [markdown]
# ### ADDING COLUMN NAME TO THE DATASET

# %%
df.columns = ['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols','Proanthocyanins', 'Color intensity', 'Hue', 'OD280', 'Proline']

# %%
df
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      13.20        1.78  2.14               11.2        100           2.65
# 1      13.16        2.36  2.67               18.6        101           2.80
# 2      14.37        1.95  2.50               16.8        113           3.85
# 3      13.24        2.59  2.87               21.0        118           2.80
# 4      14.20        1.76  2.45               15.2        112           3.27
# ..       ...         ...   ...                ...        ...            ...
# 172    13.71        5.65  2.45               20.5         95           1.68
# 173    13.40        3.91  2.48               23.0        102           1.80
# 174    13.27        4.28  2.26               20.0        120           1.59
# 175    13.17        2.59  2.37               20.0        120           1.65
# 176    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %% [markdown]
# # PERFORMING EXPLORATORY DATA ANALYSIS(EDA) ON THE DATASET

# %%
plt.rcParams["figure.figsize"] = (10, 10)
sns.heatmap(df.corr(), annot = True, linewidths=2.5 )

# %%
sns.pairplot(df)

# %%
plt.rcParams["figure.figsize"] = (15, 15)
df1.hist(bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # PLOTING THE DENDROGRAM OF THE DATASET

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(df, method = 'ward'))
plt.rcParams["figure.figsize"] = (5, 5)
plt.title('Dendrogram')
plt.xlabel('Number of clusters')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## KMEANS MODEL

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init='k-means++', random_state=32)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.rcParams["figure.figsize"] = (5, 5)
plt.title('THE ELBOW METHOD')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# ## GENERATING THE Dependent column

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', random_state=42)
y_kmeans = pd.Series(kmeans.fit_predict(df))
print(y_kmeans)
# Out:
# 0      0
# 1      0
# 2      0
# 3      2
# 4      0
#       ..
# 172    2
# 173    2
# 174    2
# 175    2
# 176    1
# Length: 177, dtype: int32

# %% [markdown]
# ### Grouping the dependent columns

# %%
y_kmeans.value_counts()
# Out:
# 1    69
# 2    62
# 0    46
# dtype: int64

# %% [markdown]
# ## APPLYING PRINCIPAL COMPONENTS ANALYSIS (PCA) to the dataset i.e, reduce the number  of faetures in the dataset using the PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca_df = pca.fit_transform(df1)

# %%
pca_df = pd.DataFrame(pca_df, columns=["PCA 1", "PCA 2"])
pca_df["Cluster"] = y_kmeans
pca_df.head(10)
# Out:
#         PCA 1      PCA 2  Cluster
# 0  304.898866  -5.139198        0
# 1  439.863485  -6.239584        0
# 2  735.039781   0.605870        0
# 3   -9.778966  18.608535        2
# 4  705.030955   0.065444        0
# 5  544.776489 -13.187861        0
# 6  550.197037  11.788199        0
# 7  299.839568  -7.950491        0
# 8  299.851951  -6.866880        0
# 9  764.882803  -7.905929        0

# %% [markdown]
# ## VISUALISING THE CLUSTERS

# %%
sns.scatterplot(x="PCA 1", y="PCA 2", hue="Cluster", data=pca_df1, palette=['green','orange','brown'], s=50)
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker="+", s=300, linewidths=3, lw=4, color="blue", zorder=10)
plt.rcParams["figure.figsize"] = (7, 7)
plt.title("WINE CATEGORY")
plt.xlabel('EACH WINE POINT ')
plt.ylabel('Eucledean Distance')
plt.show()

# %%
df["Cluster"] = y_kmeans
df.head()
# Out:
#    14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065  Cluster
# 0  1050        0
# 1  1185        0
# 2  1480        0
# 3   735        2
# 4  1450        0

# %%
sns.pairplot(df, hue="Cluster", palette=['green','orange','brown'])
plt.show()

# %% [markdown]
# ##### These above data/visualization are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines.
